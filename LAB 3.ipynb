# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("/Users/nadiam/Desktop/Lab/Lab4/Experiment 3 Data.xlsx - datasheet Python actual .csv")
df["V (m^3)"].max()
# Out:
# 0.00032854999999999999

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


ax1 = df.plot.scatter(x='V (m^3)',y='P (pascal) 059',c='RoyalBlue', label= "0.059 in")
df.plot(kind='scatter', x='V (m^3)', y='Pabs (pascal) 0.63', color='MediumOrchid', label='0.063 in', ax=ax1);
df.plot(kind='scatter', x='V (m^3)', y='pabs (pascals)78', color='SkyBlue', label='0.078 in', ax=ax1);
df.plot(kind='scatter', x='V (m^3)', y='Pabs (pascals) 98', color='Sandybrown', label='0.098 in', ax=ax1);
df.plot(kind='scatter', x='V (m^3)', y='Pabs (pascals)132', color='MediumSeaGreen', label='0.132 in', ax=ax1);

ax1.set_xlim(-1.25297e-05,0.00032854999999999999
)

ax1.set_ylabel(" Pressure (Pa)")
# Out:
# Text(0,0.5,' Pressure (Pa)')

# %%
df2=pd.read_csv("/Users/nadiam/Desktop/Lab/Lab4/Experiment 3 Data.csv - Ideal thermodynamic cycle graph.csv")
df2.max()
# Out:
# Unnamed: 0             V4
# 59            0.000366402
# P59                448159
# 62            0.000374468
# P62                386107
# 78            0.000356695
# P78                289580
# 98            0.000369979
# P98                158579
# 132           0.000593821
# P132               101058
# dtype: object

# %%
# %matplotlib inline


# ax2 = df2.plot.scatter(x='59',y='P59',c='RoyalBlue', label= "0.059 in")
# df2.plot(kind='scatter', x='62', y='P62', color='MediumOrchid', label='0.063 in', ax=ax2);
# df2.plot(kind='scatter', x='78', y='P78', color='SkyBlue', label='0.078 in', ax=ax2);
# df2.plot(kind='scatter', x='98', y='P98', color='Sandybrown', label='0.098 in', ax=ax2);
# df2.plot(kind='scatter', x='132', y='P132', color='MediumSeaGreen', label='0.132 in', ax=ax2);

# ax2.set_xlim(1.59678e-05,0.000693821)
# ax2.set_ylim(40000.1,478159)


# ax2.set_ylabel(" Pabs (Pascals)")
# ax2.set_xlabel("Volume (m^3)")


plt.plot( '59','P59', data=df2, marker='',color= 'RoyalBlue',linewidth=2,linestyle = '-.', label= "0.059 in")
plt.plot( '62', 'P62', data=df2, marker='', color='MediumOrchid', linewidth=2,linestyle = '-.', label= "0.063 in" )
plt.plot( '78', 'P78', data=df2, marker='', color='SkyBlue', linewidth=2,linestyle = '-.', label= "0.0.78 in")
plt.plot( '98', 'P98', data=df2, marker='', color='Sandybrown', linewidth=2,linestyle = '-.', label= "0.0.98 in")
plt.plot( '132', 'P132', data=df2, marker='', color='MediumSeaGreen', linewidth=2,linestyle = '-.', label= "0.132 in")

plt.xlabel("V (m^3)")
plt.ylabel("Pressure (Pa)")


plt.legend()
